# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Crop_Recommendation.csv")
data.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  ...  pH_Value    Rainfall  Crop
# 0        90          42         43  ...  6.502985  202.935536  Rice
# 1        85          58         41  ...  7.038096  226.655537  Rice
# 2        60          55         44  ...  7.840207  263.964248  Rice
# 3        74          35         40  ...  6.980401  242.864034  Rice
# 4        78          42         42  ...  7.628473  262.717340  Rice
#
# [5 rows x 8 columns]

# %%
data['Crop'].unique()
# Out:
# <StringArray>
# [       'Rice',       'Maize',    'ChickPea', 'KidneyBeans',  'PigeonPeas',
#    'MothBeans',    'MungBean',   'Blackgram',      'Lentil', 'Pomegranate',
#       'Banana',       'Mango',      'Grapes',  'Watermelon',   'Muskmelon',
#        'Apple',      'Orange',      'Papaya',     'Coconut',      'Cotton',
#         'Jute',      'Coffee']
# Length: 22, dtype: str

# %%
pd.unique(data['Crop'])
# Out:
# <StringArray>
# [       'Rice',       'Maize',    'ChickPea', 'KidneyBeans',  'PigeonPeas',
#    'MothBeans',    'MungBean',   'Blackgram',      'Lentil', 'Pomegranate',
#       'Banana',       'Mango',      'Grapes',  'Watermelon',   'Muskmelon',
#        'Apple',      'Orange',      'Papaya',     'Coconut',      'Cotton',
#         'Jute',      'Coffee']
# Length: 22, dtype: str

# %%
# pd.value_counts(data['Crop'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.value_counts(data['Crop'])
#
# AttributeError: module 'pandas' has no attribute 'value_counts'

# %%
data['Crop'].value_counts()
# Out:
# Crop
# Rice           100
# Maize          100
# ChickPea       100
# KidneyBeans    100
# PigeonPeas     100
# MothBeans      100
# MungBean       100
# Blackgram      100
# Lentil         100
# Pomegranate    100
# Banana         100
# Mango          100
# Grapes         100
# Watermelon     100
# Muskmelon      100
# Apple          100
# Orange         100
# Papaya         100
# Coconut        100
# Cotton         100
# Jute           100
# Coffee         100
# Name: count, dtype: int64

# %%
X,y = data.iloc[:,:-1], data['Crop']
X.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  ...   Humidity  pH_Value    Rainfall
# 0        90          42         43  ...  82.002744  6.502985  202.935536
# 1        85          58         41  ...  80.319644  7.038096  226.655537
# 2        60          55         44  ...  82.320763  7.840207  263.964248
# 3        74          35         40  ...  80.158363  6.980401  242.864034
# 4        78          42         42  ...  81.604873  7.628473  262.717340
#
# [5 rows x 7 columns]

# %%
X = X.reset_index(drop=True)

# %%
X_corr = X.corr()
sns.heatmap(X_corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X.values)
X_scaled = pd.DataFrame(scaled_data, columns = X.columns)
X_scaled.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature  Humidity  pH_Value  Rainfall
# 0  1.068797   -0.344551  -0.101688    -0.935587  0.472666  0.043302  1.810361
# 1  0.933329    0.140616  -0.141185    -0.759646  0.397051  0.734873  2.242058
# 2  0.255986    0.049647  -0.081939    -0.515898  0.486954  1.771510  2.921066
# 3  0.635298   -0.556811  -0.160933     0.172807  0.389805  0.660308  2.537048
# 4  0.743673   -0.344551  -0.121436    -1.083647  0.454792  1.497868  2.898373

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state = 42)

param_grid ={
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5,10],
    "min_samples_split": [2,5,10],
    "min_samples_leaf": [1,2,4]
}

clf = DecisionTreeClassifier(random_state=42)
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
results = pd.DataFrame(grid_search.cv_results_)
results.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.006108      0.001372  ...        0.006327                5
# 1       0.004252      0.000125  ...        0.006818                1
# 2       0.003792      0.000111  ...        0.007914                1
# 3       0.003804      0.000153  ...        0.010068                5
# 4       0.003783      0.000084  ...        0.009439                8
#
# [5 rows x 17 columns]

# %%
best_params = grid_search.best_params_
best_clf = DecisionTreeClassifier(**best_params, random_state=42)
best_clf.fit(X_train, y_train)
y_pred = best_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"Best Parameters: {best_params}")
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test F1 Score: {f1:.4f}")
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5}
# Test Accuracy: 0.9864
# Test F1 Score: 0.9863

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

param_grid_xgb = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'subsample': [0.8, 1.0]
}

grid_search_xgb = GridSearchCV(estimator=XGBClassifier(random_state=42), param_grid=param_grid_xgb, cv=5, scoring='accuracy')
grid_search_xgb.fit(X_train, y_train)

results_xgb = pd.DataFrame(grid_search_xgb.cv_results_)
results_xgb.head()
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       1.361480      0.010216  ...        0.008115               15
# 1       1.305154      0.008976  ...        0.010870               16
# 2       2.774752      0.077534  ...        0.007832                9
# 3       2.631586      0.042176  ...        0.010384               12
# 4       1.690756      0.006530  ...        0.008617               13
#
# [5 rows x 17 columns]

# %%
best_params_xgb = grid_search_xgb.best_params_
best_xgb_clf = XGBClassifier(**best_params_xgb, random_state=42)
best_xgb_clf.fit(X_train, y_train)
y_pred_xgb = best_xgb_clf.predict(X_test)
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
f1_xgb = f1_score(y_test, y_pred_xgb, average='weighted')
print(f"Best XGBoost Parameters: {best_params_xgb}")
print(f"XGBoost Test Accuracy: {accuracy_xgb:.4f}")
print(f"XGBoost Test F1 Score: {f1_xgb:.4f}")
# Out:
# Best XGBoost Parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}
# XGBoost Test Accuracy: 0.9886
# XGBoost Test F1 Score: 0.9886
